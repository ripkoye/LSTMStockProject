# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Stock-Market-Data/sp500_daily_stock_prices(10 years).csv")
print(df.columns)
print(df.head())
# Out:
# Index(['Date', 'A', 'AA', 'AAPL', 'ABBV', 'ABC', 'ABT', 'ACN', 'ADBE', 'ADI',
#        ...
#        'X', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'XYL', 'YUM', 'ZION'],
#       dtype='object', length=479)
#          Date          A         AA      AAPL  ABBV        ABC       ABT  \
# 0  2003-07-31  13.790836  53.019848  1.019303   NaN  12.739487  9.022574
# 1  2003-08-01  13.676599  51.759747  1.002379   NaN  12.579965  8.859362
# 2  2003-08-04  13.682946  52.256149  1.025589   NaN  12.398233  8.850165
# 3  2003-08-05  13.219654  51.206055  0.985455   NaN  12.111500  8.700747
# 4  2003-08-06  13.060995  50.783653  0.949190   NaN  11.752071  8.873152
#
#          ACN       ADBE        ADI  ...          X       XEL         XL  \
# 0  15.108545  16.333433  26.962475  ...  13.784163  7.946304  53.450195
# 1  15.816516  16.268559  28.070812  ...  13.626727  7.858501  50.491951
# 2  15.660917  16.523066  28.227112  ...  14.265206  7.803621  51.500431
# ...

# %%
print(df.tail())
# Out:
#             Date          A         AA        AAPL       ABBV        ABC  \
# 2871  2014-12-24  39.798771  36.984089  105.600830  59.121506  87.124428
# 2872  2014-12-26  40.040676  37.101357  107.467529  59.809086  87.038811
# 2873  2014-12-29  39.992302  37.101357  107.392113  59.951946  87.152954
# 2874  2014-12-30  40.031002  37.171711  106.081627  59.201881  86.820061
# 2875  2014-12-31  39.614918  37.030998  104.064087  58.433949  85.754784
#
#             ABT        ACN       ADBE        ADI  ...          X        XEL  \
# 2871  42.459160  84.954086  74.739998  52.523140  ...  25.622986  32.722038
# 2872  42.598511  84.898285  74.669998  52.124886  ...  25.758299  33.038155
# 2873  42.366241  84.209862  74.129997  51.939648  ...  25.999937  33.643284
# 2874  42.449860  83.902878  73.080002  51.458046  ...  26.212574  32.857521
# 2875  41.827370  83.084213  72.699997  51.420998  ...  25.845289  32.442055
#
# ...

# %%
\textbf{Seems like the last date is 2014-12-31}
# Out:
#   Cell In[14], line 1
#     $$\textbf{Seems like the last date is 2014-12-31}$$
#     ^
# SyntaxError: invalid syntax
